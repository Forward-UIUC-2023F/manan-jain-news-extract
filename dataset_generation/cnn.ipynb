# %%
import sys
sys.path.append("../modules/")
import scraper
from bs4 import BeautifulSoup

html = scraper.fetch_html("https://www.cnn.com/", waitUntil='static')
soup = BeautifulSoup(html, 'html.parser')
soup = scraper.clean_html(soup)
soup = scraper.squash_nested_divs(soup)
tags = scraper.extract_tags(soup)

for i, tag in enumerate(tags):
    print(f'{i}: {tag}\n')
# Out:
# 0: <a class="brand-logo__logo-link" data-zjs="click" data-zjs-component_id="https://www.cnn.com" data-zjs-component_text="Main Logo" data-zjs-component_type="icon" data-zjs-container_id="" data-zjs-container_type="navigation" data-zjs-destination_url="https://www.cnn.com" data-zjs-page_type="section" data-zjs-page_variant="landing_homepage" href="https://www.cnn.com" title="CNN logo">
# <span class="brand-logo__logo">
#
# </span>
# </a>
#
# 1: <a class="header__nav-item-link" data-zjs="click" data-zjs-component_id="https://www.cnn.com/us" data-zjs-component_text="US" data-zjs-component_type="link" data-zjs-container_id="cms.cnn.com/_components/header/instances/cnn-v1@published" data-zjs-container_type="navigation" data-zjs-destination_url="https://www.cnn.com/us" data-zjs-navigation-location="header" data-zjs-navigation-type="main" data-zjs-page_type="section" data-zjs-page_variant="landing_homepage" href="https://www.cnn.com/us">
#
#                   US
#                 </a>
#
# ...

# %%
import pandas as pd

df = pd.DataFrame(tags)
df.columns = ['html']
df['is_article'] = 0
df['i'] = df.index
df.head(10)
print(len(df['html']))
# Out:
# 546

# %%
for i, item in enumerate(df.iterrows()):
    soup = BeautifulSoup(item[1].html, 'html.parser')
    res = soup.find(class_="container_lead-package__title-url")
    if df.loc[i, 'is_article'] == 0 and res:
        df.loc[i, 'is_article'] = 1
        
len(df[df['is_article']==1])
# Out:
# 4

# %%
for i, item in enumerate(df.iterrows()):
    soup = BeautifulSoup(item[1].html, 'html.parser')
    res = soup.find(class_="container__link--type-article")
    if df.loc[i, 'is_article'] == 0 and res:
        df.loc[i, 'is_article'] = 1
        
len(df[df['is_article']==1])
# Out:
# 149

# %%
for i, item in enumerate(df.iterrows()):
    soup = BeautifulSoup(item[1].html, 'html.parser')
    res = soup.find(class_="container__link--type-live-story")
    if df.loc[i, 'is_article'] == 0 and res:
        df.loc[i, 'is_article'] = 1
        
len(df[df['is_article']==1])
# Out:
# 151

# %%
for i, item in enumerate(df.iterrows()):
    soup = BeautifulSoup(item[1].html, 'html.parser')
    res = soup.find(class_="container__link--type-live-story")
    if df.loc[i, 'is_article'] == 0 and res:
        df.loc[i, 'is_article'] = 1
        
len(df[df['is_article']==1])
# Out:
# 151

# %%
for i, item in enumerate(df.iterrows()):
    soup = BeautifulSoup(item[1].html, 'html.parser')
    res = soup.find(class_="container_list-headlines-with-images__link")
    if df.loc[i, 'is_article'] == 0 and res:
        df.loc[i, 'is_article'] = 1
        
len(df[df['is_article']==1])
# Out:
# 155

# %%
for i, item in enumerate(df.iterrows()):
    soup = BeautifulSoup(item[1].html, 'html.parser')
    res = soup.find(class_="container__headline-text")
    if df.loc[i, 'is_article'] == 0 and res:
        df.loc[i, 'is_article'] = 1
        
len(df[df['is_article']==1])
# Out:
# 192

# %%
df.loc[177:179, 'is_article'] = 0
df.loc[180:187, 'is_article'] = 0

# %%
total = 0
for i, item in enumerate(df.iterrows()):
    if df.loc[i, 'is_article'] == 1:
        total+=1
        temp = item[1]['html'].replace(r'\n', '')
        print(f"{item[1]['i']}: {temp}\n")
        
print(total)
# Out:
# 188: <a class="container__title-url container_lead-package__title-url" href="/2024/01/06/politics/new-january-6-video-capitol-riot/index.html">
# <h2 class="container__title_url-text container_lead-package__title_url-text" data-editable="title">Jan. 6 video shows tense exchange between GOP congressmen and rioters</h2>
# <p class="container__title_url-sub-text container_lead-package__title_url-sub-text">Show all</p>
# </a>
#
# 189: <a class="container__link container__link--type-article container_lead-package__link container_lead-package__left container_lead-package__light" data-link-type="article" href="/2024/01/06/politics/new-january-6-video-capitol-riot/index.html">
#
#
#
#
#
# ...

# %%
# del df['i']
# df.to_csv("data/cnn.txt", index=False)
